# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
class_info = pd.read_csv("../data/skillshare_2022_classes.csv", index_col=0)
print(class_info.columns)
class_info.head()
# Out:
# Index(['class_id', 'class_title', 'create_time', 'description', 'takeaway',
#        'category', 'subcategory', 'status', 'is_featured', 'is_premium_only',
#        'publish_time', 'publish_date', 'teacher_uid', 'teacher_name',
#        'is_top_teacher', 'teacher_create_time', 'teacher_account_age',
#        'is_original', 'class_type', 'quality_grade', 'quality_grade_letter',
#        'is_quality_class', 'grade_note', 'n_reviews', 'review_avg', 'level_id',
#        'level', 'has_been_staff_pick', 'n_times_staff_pick',
#        'first_staff_pick_time', 'last_staff_pick_time', 'has_project',
#        'project_title', 'sku', 'class_detail_page_link',
#        'total_video_duration', 'n_lessons', 'trailer_duration',
#        'first_lesson_duration', 'class_display_name', 'image_huge', 'language',
#        'language_grade_notes_1', 'language_grade_notes_2',
#        'language_grade_notes_3', 'language_grade_notes_all',
#        'has_non_english_content', 'non_english_language_1', 'class_origin',
#        'class_origin_raw', 'published_class_number',
#        'teacher_first_publish_time', 'is_last_published_class',
#        'is_first_original_class', 'is_first_quality_class'],
#       dtype='object')
# /tmp/ipykernel_10279/2977482116.py:1: DtypeWarning: Columns (45) have mixed types. Specify dtype option on import or set low_memory=False.
#   class_info = pd.read_csv("../data/skillshare_2022_classes.csv", index_col=0)
#    class_id                                        class_title  \
# 0     23577         A Crash Course in Photographic Composition
# 1     51370               Drawing Time: Illustrator Techniques
# 2     55284  Perfect Southern Fried Chicken + Buttermilk Bi...
# 3     65056  EasyDSLR: Master your Digital Camera in less t...
# 4    100968  Pattern Design: Creating Repeat Patterns From ...
#
#            create_time                                        description  \
# 0  2013-01-22 17:41:39  <p>This class is for anybody who wants to crea...
# 1  2013-01-31 23:54:50  <p><img src="https://static.skillshare.com/upl...
# 2  2013-02-01 23:50:57  <p><strong>Make The Best Southern Fried Chicke...
# 3  2013-02-05 00:16:27  <p>So you finally got that DSLR camera you've ...
# 4  2013-03-30 04:02:06  <p>Ever wanted to create your own hand-drawn p...
#
#    takeaway   category     subcategory     status  is_featured  \
# 0       NaN   Creative     Photography  published         True
# 1       NaN   Creative    Illustration  published         True
# 2       NaN  Lifestyle        Culinary  published         True
# 3       NaN        NaN     Photography  published         True
# 4       NaN   Creative  Graphic Design  published         True
#
#    is_premium_only  ... language_grade_notes_all has_non_english_content  \
# 0             True  ...                      NaN                   False
# 1             True  ...                      NaN                   False
# 2             True  ...                      NaN                   False
# 3             True  ...                      NaN                   False
# 4             True  ...                      NaN                   False
#
#    non_english_language_1 class_origin  class_origin_raw  \
# 0                     NaN        Other         No Source
# 1                     NaN        Other         No Source
# 2                     NaN        Other         No Source
# 3                     NaN        Other         No Source
# 4                     NaN        Other         No Source
#
#   published_class_number  teacher_first_publish_time  is_last_published_class  \
# 0                      1         2013-01-22 17:41:39                     True
# 1                      1         2013-01-31 23:54:50                     True
# 2                      1         2013-02-01 23:50:57                     True
# 3                      1         2013-02-05 00:16:27                     True
# 4                      1         2013-03-30 04:02:06                     True
#
#   is_first_original_class  is_first_quality_class
# 0                   False                    True
# 1                   False                   False
# 2                   False                   False
# 3                   False                   False
# 4                   False                   False
#
# [5 rows x 55 columns]

# %%
# Remove HTML tags from descriptions
# i.e. anything between angled brackets
class_info.description = class_info.description.str\
    .replace(r'<[^<>]*>', '', regex=True)

class_info.description
# Out:
# 0        This class is for anybody who wants to create ...
# 1        \nAI Comic Art will cover all concepts relativ...
# 2        Make The Best Southern Fried Chicken of Your L...
# 3        So you finally got that DSLR camera you've bee...
# 4        Ever wanted to create your own hand-drawn patt...
#                                ...
# 44470    In this course I teach you how to make a pillo...
# 44471    Have you covered the basics of piano, but want...
# 44472    If you want to become an illustrator there’s n...
# 44473    Welcome Future Event Planners. \nWe Ensure tha...
# 44474    Are you looking for learning easy flowers usin...
# Name: description, Length: 44475, dtype: object

# %%
# Just use 'create time' year
class_info.create_time = pd.to_datetime(class_info.create_time)
class_info['created_year'] = class_info.create_time.dt.year
class_info.created_year
# Out:
# 0        2013
# 1        2013
# 2        2013
# 3        2013
# 4        2013
#          ...
# 44470    2022
# 44471    2022
# 44472    2022
# 44473    2022
# 44474    2022
# Name: created_year, Length: 44475, dtype: int64

# %%
class_info = pd.merge(
    class_info[["class_id", "description", "is_top_teacher", "created_year"]],
    pd.get_dummies(class_info.category),
    left_index=True,
    right_index=True
)
class_info
# Out:
#        class_id                                        description  \
# 0         23577  This class is for anybody who wants to create ...
# 1         51370  \nAI Comic Art will cover all concepts relativ...
# 2         55284  Make The Best Southern Fried Chicken of Your L...
# 3         65056  So you finally got that DSLR camera you've bee...
# 4        100968  Ever wanted to create your own hand-drawn patt...
# ...         ...                                                ...
# 44470    582681  In this course I teach you how to make a pillo...
# 44471    583753  Have you covered the basics of piano, but want...
# 44472    583862  If you want to become an illustrator there’s n...
# 44473    567663  Welcome Future Event Planners. \nWe Ensure tha...
# 44474    583624  Are you looking for learning easy flowers usin...
#
#        is_top_teacher  created_year  Business  Creative  Lifestyle  Technology
# 0               False          2013         0         1          0           0
# 1               False          2013         0         1          0           0
# 2               False          2013         0         0          1           0
# 3               False          2013         0         0          0           0
# 4               False          2013         0         1          0           0
# ...               ...           ...       ...       ...        ...         ...
# 44470           False          2022         0         0          1           0
# 44471           False          2022         0         1          0           0
# 44472           False          2022         0         1          0           0
# 44473           False          2022         1         0          0           0
# 44474           False          2022         0         1          0           0
#
# [44475 rows x 8 columns]

# %%
# Vectorize description text
vectorizer = TfidfVectorizer(stop_words="english")
vectorized_text = vectorizer.fit_transform(class_info.description)
vectorized_text.shape
# Out:
# (44475, 100220)

# %%
class_info
# Out:
#        class_id                                        description  \
# 0         23577  This class is for anybody who wants to create ...
# 1         51370  \nAI Comic Art will cover all concepts relativ...
# 2         55284  Make The Best Southern Fried Chicken of Your L...
# 3         65056  So you finally got that DSLR camera you've bee...
# 4        100968  Ever wanted to create your own hand-drawn patt...
# ...         ...                                                ...
# 44470    582681  In this course I teach you how to make a pillo...
# 44471    583753  Have you covered the basics of piano, but want...
# 44472    583862  If you want to become an illustrator there’s n...
# 44473    567663  Welcome Future Event Planners. \nWe Ensure tha...
# 44474    583624  Are you looking for learning easy flowers usin...
#
#        is_top_teacher  created_year  Business  Creative  Lifestyle  Technology
# 0               False          2013         0         1          0           0
# 1               False          2013         0         1          0           0
# 2               False          2013         0         0          1           0
# 3               False          2013         0         0          0           0
# 4               False          2013         0         1          0           0
# ...               ...           ...       ...       ...        ...         ...
# 44470           False          2022         0         0          1           0
# 44471           False          2022         0         1          0           0
# 44472           False          2022         0         1          0           0
# 44473           False          2022         1         0          0           0
# 44474           False          2022         0         1          0           0
#
# [44475 rows x 8 columns]

# %%
# Non negative matrix factorization
nmf = NMF(n_components=20)
nmf.fit(vectorized_text)
nmf.components_.shape
# Out:
# (20, 100220)

# %%
feature_names = vectorizer.get_feature_names_out()
for topic_index, topic in enumerate(nmf.components_):
    feature_indexes = np.argsort(topic)[::-1]
    print("Topic", topic_index + 1, end=": ")
    print(feature_names[feature_indexes[:10]])
# Out:
# Topic 1: ['class' 'll' 'learn' 'create' 'make' 'use' 'using' 'different' 'need'
#  'simple']
# Topic 2: ['watercolor' 'painting' 'paint' 'wet' 'color' 'paper' 'brush' 'colors'
#  'techniques' 'paintings']
# Topic 3: ['lunch' 'graphic' 'design' 'adobe' 'class' 'illustrator' 'amp' '10' 'acr'
#  'patterns']
# Topic 4: ['drawing' 'draw' 'character' 'pencil' 'drawings' 'shapes' 'portrait'
#  'characters' 'pencils' 'face']
# Topic 5: ['animation' 'effects' 'motion' 'animate' 'animations' 'character'
#  'graphics' 'adobe' 'animated' 'animating']
# Topic 6: ['course' 'learn' 'll' 'learning' 'students' 'knowledge' 'courses' 'end'
#  'start' 'make']
# Topic 7: ['website' 'wordpress' 'web' 'css' 'html' 'javascript' 'page' 'websites'
#  'code' 'build']
# Topic 8: ['writing' 'write' 'story' 'book' 'writer' 'character' 'writers'
#  'creative' 'novel' 'characters']
# Topic 9: ['photoshop' 'adobe' 'images' 'photo' 'photos' 'image' 'color' 'effect'
#  'create' 'digital']
# Topic 10: ['video' 'editing' 'videos' 'youtube' 'pro' 'premiere' 'edit' 'audio'
#  'camera' 'channel']
# Topic 11: ['business' 'marketing' 'social' 'brand' 'media' 'content' 'instagram'
#  'strategy' 'sales' 'facebook']
# Topic 12: ['procreate' 'ipad' 'brushes' 'app' 'digital' 'illustration' 'art' 'brush'
#  'use' 'create']
# Topic 13: ['english' 'grammar' 'language' 'native' 'vocabulary' 'speaking' 'speak'
#  'phrases' 'words' 'lesson']
# Topic 14: ['data' 'python' 'programming' 'excel' 'code' 'language' 'science'
#  'functions' 'learning' 'sql']
# Topic 15: ['music' 'guitar' 'chords' 'play' 'piano' 'chord' 'song' 'playing' 'songs'
#  'theory']
# Topic 16: ['3d' 'blender' 'modeling' 'model' 'render' 'character' 'create' '4d'
#  'scene' 'cinema']
# Topic 17: ['step' 'project' 'art' 'child' 'process' 'creative' 'paper' 'children'
#  'complete' 'artistic']
# Topic 18: ['life' 'time' 'work' 'people' 'day' 'help' 'goals' 'want' 'productivity'
#  'way']
# Topic 19: ['design' 'ux' 'logo' 'designer' 'designs' 'designing' 'ui' 'canva'
#  'graphic' 'designers']
# Topic 20: ['illustrator' 'adobe' 'pattern' 'tool' 'vector' 'patterns' 'create'
#  'illustration' 'shapes' 'tools']

# %%
# This step takes awhile
# Transform from each description via LDA to a topic (top topic)
class_info["my_topic"] = class_info.description.apply(lambda text: np.argmax(nmf.transform(vectorizer.transform([text]))))
class_info["my_topic"]
# Out:
# 0         0
# 1        19
# 2        17
# 3        17
# 4        19
#          ..
# 44470    16
# 44471    14
# 44472     3
# 44473     5
# 44474     1
# Name: my_topic, Length: 44475, dtype: int64

# %%
starts = pd.read_csv("skillshare_2022_starts_views_combined.csv", index_col=0)
class_w_starts = pd.merge(class_info[["class_id", "my_topi"]], starts, left_on="class_id", right_on="class_id", how="outer")
class_w_starts
# Out:
#                 uid  class_id  lesson_id  lesson_number is_trailer  \
# 0         1128075.0  121998.0  1533011.0            6.0      False
# 1         1128075.0  121998.0  1533013.0            7.0      False
# 2         1128075.0  240747.0  2841973.0            0.0       True
# 3         1128075.0  240747.0  2841972.0            1.0      False
# 4         1128075.0  240747.0  2841992.0            2.0      False
# ...             ...       ...        ...            ...        ...
# 20122360        NaN       NaN        NaN            NaN        NaN
# 20122361        NaN       NaN        NaN            NaN        NaN
# 20122362        NaN       NaN        NaN            NaN        NaN
# 20122363        NaN       NaN        NaN            NaN        NaN
# 20122364        NaN       NaN        NaN            NaN        NaN
#
#           video_duration  view_date    sum         id    user_uid  ...  \
# 0                  407.0 2022-01-07  333.0  8815609.0   1128075.0  ...
# 1                   93.0 2022-01-07   92.0  8815609.0   1128075.0  ...
# 2                   73.0 2022-01-07   74.0  8815609.0   1128075.0  ...
# 3                   90.0 2022-01-07   90.0  8815609.0   1128075.0  ...
# 4                  319.0 2022-01-07  320.0  8815609.0   1128075.0  ...
# ...                  ...        ...    ...        ...         ...  ...
# 20122360             NaN        NaT    NaN  9454516.0  26283105.0  ...
# 20122361             NaN        NaT    NaN  9454622.0  26283254.0  ...
# 20122362             NaN        NaT    NaN  9454815.0  26283973.0  ...
# 20122363             NaN        NaT    NaN  9454818.0  26266500.0  ...
# 20122364             NaN        NaT    NaN  9454828.0  26284017.0  ...
#
#          is_direct_to_paid trial_length_offer had_trial sub_utm_source  \
# 0                    False          One Month      True            NaN
# 1                    False          One Month      True            NaN
# 2                    False          One Month      True            NaN
# 3                    False          One Month      True            NaN
# 4                    False          One Month      True            NaN
# ...                    ...                ...       ...            ...
# 20122360             False          One Month      True            NaN
# 20122361             False              Other     False            NaN
# 20122362             False           One Week      True            NaN
# 20122363             False           One Week      True       (direct)
# 20122364             False          One Month      True         Google
#
#                                     sub_utm_campaign sub_utm_medium  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# ...                                              ...            ...
# 20122360                                         NaN            NaN
# 20122361                                         NaN            NaN
# 20122362                                         NaN            NaN
# 20122363                                         NaN         (none)
# 20122364  Croud_Search_Google_LA_BR_PT_BOF_Non-Brand     paidsearch
#
#                            sub_utm_term          sub_utm_channel  \
# 0                                   NaN                  Missing
# 1                                   NaN                  Missing
# 2                                   NaN                  Missing
# 3                                   NaN                  Missing
# 4                                   NaN                  Missing
# ...                                 ...                      ...
# 20122360                            NaN           Organic Search
# 20122361                            NaN           Organic Search
# 20122362                            NaN           Organic Search
# 20122363                            NaN                   Direct
# 20122364  como+fazer+anima%C3%A7%C3%A3o  Paid Search (Non-brand)
#
#                   referral_source eligible_trial_number
# 0                             NaN                   6.0
# 1                             NaN                   6.0
# 2                             NaN                   6.0
# 3                             NaN                   6.0
# 4                             NaN                   6.0
# ...                           ...                   ...
# 20122360  https://www.google.com/                   1.0
# 20122361  https://www.google.com/                   NaN
# 20122362  https://www.google.com/                   1.0
# 20122363                      NaN                   1.0
# 20122364                      NaN                   1.0
#
# [20122365 rows x 82 columns]

# %%
account_and_views_info = account_and_views_info[account_and_views_info.trial_length_offer.isin(["One Month", "One Week"])]
account_and_views_info
# Out:
#                 uid  class_id  lesson_id  lesson_number is_trailer  \
# 0         1128075.0  121998.0  1533011.0            6.0      False
# 1         1128075.0  121998.0  1533013.0            7.0      False
# 2         1128075.0  240747.0  2841973.0            0.0       True
# 3         1128075.0  240747.0  2841972.0            1.0      False
# 4         1128075.0  240747.0  2841992.0            2.0      False
# ...             ...       ...        ...            ...        ...
# 20122359        NaN       NaN        NaN            NaN        NaN
# 20122360        NaN       NaN        NaN            NaN        NaN
# 20122362        NaN       NaN        NaN            NaN        NaN
# 20122363        NaN       NaN        NaN            NaN        NaN
# 20122364        NaN       NaN        NaN            NaN        NaN
#
#           video_duration  view_date    sum         id    user_uid  ...  \
# 0                  407.0 2022-01-07  333.0  8815609.0   1128075.0  ...
# 1                   93.0 2022-01-07   92.0  8815609.0   1128075.0  ...
# 2                   73.0 2022-01-07   74.0  8815609.0   1128075.0  ...
# 3                   90.0 2022-01-07   90.0  8815609.0   1128075.0  ...
# 4                  319.0 2022-01-07  320.0  8815609.0   1128075.0  ...
# ...                  ...        ...    ...        ...         ...  ...
# 20122359             NaN        NaT    NaN  9454467.0  26283012.0  ...
# 20122360             NaN        NaT    NaN  9454516.0  26283105.0  ...
# 20122362             NaN        NaT    NaN  9454815.0  26283973.0  ...
# 20122363             NaN        NaT    NaN  9454818.0  26266500.0  ...
# 20122364             NaN        NaT    NaN  9454828.0  26284017.0  ...
#
#          is_direct_to_paid trial_length_offer had_trial sub_utm_source  \
# 0                    False          One Month      True            NaN
# 1                    False          One Month      True            NaN
# 2                    False          One Month      True            NaN
# 3                    False          One Month      True            NaN
# 4                    False          One Month      True            NaN
# ...                    ...                ...       ...            ...
# 20122359             False          One Month      True        youtube
# 20122360             False          One Month      True            NaN
# 20122362             False           One Week      True            NaN
# 20122363             False           One Week      True       (direct)
# 20122364             False          One Month      True         Google
#
#                                     sub_utm_campaign         sub_utm_medium  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
# ...                                              ...                    ...
# 20122359                         2022-05-01-pjiggles  paid-influencer-video
# 20122360                                         NaN                    NaN
# 20122362                                         NaN                    NaN
# 20122363                                         NaN                 (none)
# 20122364  Croud_Search_Google_LA_BR_PT_BOF_Non-Brand             paidsearch
#
#                            sub_utm_term          sub_utm_channel  \
# 0                                   NaN                  Missing
# 1                                   NaN                  Missing
# 2                                   NaN                  Missing
# 3                                   NaN                  Missing
# 4                                   NaN                  Missing
# ...                                 ...                      ...
# 20122359                            NaN       Youtube Influencer
# 20122360                            NaN           Organic Search
# 20122362                            NaN           Organic Search
# 20122363                            NaN                   Direct
# 20122364  como+fazer+anima%C3%A7%C3%A3o  Paid Search (Non-brand)
#
#                   referral_source eligible_trial_number
# 0                             NaN                   6.0
# 1                             NaN                   6.0
# 2                             NaN                   6.0
# 3                             NaN                   6.0
# 4                             NaN                   6.0
# ...                           ...                   ...
# 20122359                      NaN                   1.0
# 20122360  https://www.google.com/                   1.0
# 20122362  https://www.google.com/                   1.0
# 20122363                      NaN                   1.0
# 20122364                      NaN                   1.0
#
# [12728868 rows x 82 columns]

# %%
account_and_views_info.view_date = pd.to_datetime(account_and_views_info.view_date)
account_and_views_info.create_time = pd.to_datetime(account_and_views_info.create_time)

account_and_views_info["day_of_trial"] = account_and_views_info.view_date - account_and_views_info.create_time
account_and_views_info.dropna(subset=["day_of_trial"], inplace=True)
account_and_views_info["day_of_trial"]
# Out:
# /tmp/ipykernel_76020/1087726984.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   account_and_views_info.view_date = pd.to_datetime(account_and_views_info.view_date)
# /tmp/ipykernel_76020/1087726984.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   account_and_views_info.create_time = pd.to_datetime(account_and_views_info.create_time)
# /tmp/ipykernel_76020/1087726984.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   account_and_views_info["day_of_trial"] = account_and_views_info.view_date - account_and_views_info.create_time
# /tmp/ipykernel_76020/1087726984.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   account_and_views_info.dropna(subset=["day_of_trial"], inplace=True)
# 0            2 days 20:36:33
# 1            2 days 20:36:33
# 2            2 days 20:36:33
# 3            2 days 20:36:33
# 4            2 days 20:36:33
#                   ...
# 19977675    40 days 15:27:17
# 19977676    42 days 05:21:33
# 19977677   -1 days +05:52:51
# 19977678    42 days 05:21:33
# 19977679   -1 days +05:52:51
# Name: day_of_trial, Length: 12639366, dtype: timedelta64[ns]
