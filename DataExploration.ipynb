# %%
import numpy as np
import pandas as pd

# %%
files = !ls data/*.csv

# %%
print(files[2])
follows_df = pd.read_csv(files[2], index_col=0)
follows_df
# Out:
# data/skillshare_2022_follows.csv
#         follower_uid  target_uid          follow_time  is_follower_deleted  \
# 0               8994      797923  2022-03-01 14:40:40                False
# 1               8994     3407987  2022-02-25 17:55:50                False
# 2               8994    10136582  2022-02-25 17:54:30                False
# 3               8994    13421205  2022-03-01 14:36:48                False
# 4              46649     5098613  2022-05-22 13:22:00                False
# ...              ...         ...                  ...                  ...
# 341679      26283948     3045460  2022-06-24 13:21:59                False
# 341680      26284046     2005611  2022-06-12 08:33:55                False
# 341681      26284046     2603278  2022-06-14 01:08:32                False
# 341682      26284089      381358  2022-06-01 02:22:46                False
# 341683      26284089     2168285  2022-05-31 23:56:28                False
#
# ...

# %%
starts_df = pd.read_csv('data/skillshare_2022_starts.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 starts_df = pd.read_csv('data/skillshare_2022_starts.csv', index_col=0)
#
# File /usr/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
starts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 655203 entries, 0 to 655202
# Data columns (total 75 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     655203 non-null  int64
#  1   id                             655203 non-null  int64
#  2   user_uid                       649630 non-null  float64
#  3   is_active                      655203 non-null  bool
#  4   create_time                    655203 non-null  object
#  5   update_time                    655203 non-null  object
#  6   realized_end_time              655203 non-null  object
#  7   expiration_time                459857 non-null  object
#  8   first_payment_time             209937 non-null  object
#  9   last_payment_time              209937 non-null  object
#  10  next_billing_time              189660 non-null  object
#  11  last_payment_attempt           320674 non-null  object
# ...

# %%
starts_df = starts_df[starts_df['plan_length'] == 12]
starts_df = starts_df[starts_df['is_team'] == False]
starts_df = starts_df[starts_df['is_scholarship'] == False]

# %%
starts_df = starts_df[starts_df['is_direct_to_paid'] == False]
starts_df = starts_df[starts_df['had_trial'] == True]

# %%
starts_df = starts_df[starts_df['trial_length_offer'].isin(['One Week', 'One Month'])]

# %%
starts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483026 entries, 1 to 655202
# Data columns (total 75 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     483026 non-null  int64
#  1   id                             483026 non-null  int64
#  2   user_uid                       483026 non-null  float64
#  3   is_active                      483026 non-null  bool
#  4   create_time                    483026 non-null  object
#  5   update_time                    483026 non-null  object
#  6   realized_end_time              483026 non-null  object
#  7   expiration_time                358374 non-null  object
#  8   first_payment_time             142933 non-null  object
#  9   last_payment_time              142933 non-null  object
#  10  next_billing_time              122519 non-null  object
#  11  last_payment_attempt           229388 non-null  object
# ...
